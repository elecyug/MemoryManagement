# %% [raw]
# #Q1. Discuss the scenarios where multithreading is preferable to multiprocessing and scenarios where
# #    multiprocessing is a better choice.
#
#
#
# Multithreading is preferable for I/O-bound tasks like file handling, network operations, or user input, where the program spends time waiting for external resources. Threads can run concurrently, improving efficiency by overlapping I/O operations. It’s also ideal for scenarios requiring shared memory, as threads within the same process can communicate and share data without significant overhead. Additionally, multithreading is suitable for environments with limited resources since threads are lightweight and consume fewer resources than processes.
#
# Conversely, multiprocessing is better for CPU-bound tasks, such as heavy computations, where full CPU core utilization is needed. It avoids the Global Interpreter Lock (GIL) in Python, enabling true parallelism. Multiprocessing is also preferable when tasks require memory isolation, as processes run independently with separate memory spaces, enhancing robustness and preventing data corruption. Moreover, it is ideal for scalable and fault-tolerant systems, such as distributed systems, where processes can run across multiple machines, ensuring that failures in one process do not affect others.
# In summary, use multithreading for I/O-bound tasks and shared memory scenarios, and multiprocessing for CPU-bound tasks, memory isolation, and scalable, fault-tolerant systems.

# %% [raw]
# #Q2. Describe what a process pool is and how it helps in managing multiple processes efficiently.
#
#
#
#
# A process pool is a collection of worker processes that are managed together and used to perform tasks concurrently. It is a common pattern in parallel computing to efficiently handle multiple tasks by distributing them among several processes.
#
# Key Points of a Process Pool:
#
# Resource Management: A process pool manages a fixed number of processes, allowing for efficient resource allocation. Instead of creating and destroying processes for each task, which is expensive in terms of time and system resources, a pool of processes is reused.
#
# Task Distribution: When a task is submitted to the process pool, it is assigned to an available worker process. This distribution helps in parallelizing the workload, allowing multiple tasks to be processed simultaneously.
#
# Scalability: Process pools can scale with the number of available CPU cores. By adjusting the pool size, you can control the number of processes running concurrently, which can help in optimizing performance for different workloads.
#
# Efficient Management: The process pool abstracts away the complexities of process creation and management. You interact with the pool using a higher-level API, which handles process scheduling and synchronization internally.

# %% [raw]
# #Q3. Explain what multiprocessing is and why it is used in Python programs.
#
#
#
# Multiprocessing is a technique in computing that involves running multiple processes concurrently to perform tasks in parallel. It is used to leverage multiple CPU cores to improve performance and efficiency.
#
# Key Concepts of Multiprocessing:
#
# Process: A process is an independent unit of execution with its own memory space. Each process runs independently and does not share memory with other processes unless explicitly managed (e.g., through inter-process communication).
#
# Concurrency: Multiprocessing allows multiple processes to run concurrently, meaning they can execute simultaneously and independently. This is particularly useful for tasks that are CPU-bound, where multiple processes can utilize different CPU cores.
#
# Parallelism: By running multiple processes in parallel, you can achieve true parallelism, which can lead to significant performance improvements, especially on multi-core systems.
#
# Why Multiprocessing is Used in Python:
#
# Global Interpreter Lock (GIL): Python's standard implementation (CPython) has a Global Interpreter Lock that prevents multiple native threads from executing Python bytecodes simultaneously. This can limit the performance of multi-threaded programs for CPU-bound tasks. Multiprocessing circumvents the GIL by using separate processes, each with its own Python interpreter and memory space.
#
# CPU-bound Tasks: For tasks that require intensive computation (e.g., numerical simulations, data processing), multiprocessing allows you to fully utilize multiple CPU cores, thus improving execution speed and efficiency.
#
# Task Isolation: Processes in multiprocessing are isolated from each other, which means that crashes or errors in one process do not affect others. This isolation can improve the stability of applications.
#
# Parallel Processing: Multiprocessing enables parallel execution of tasks, making it suitable for workloads that can be broken down into smaller, independent tasks.

# %%
# Q4. Write a Python program using multithreading where one thread adds numbers to a list, and another
#     thread removes numbers from the list. Implement a mechanism to avoid race conditions using
#     threading.Lock.



import threading
import time

# Shared list between threads
shared_list = []

# Create a lock object to avoid race conditions
list_lock = threading.Lock()

# Function for adding numbers to the list
def add_to_list():
    list1 = [1, 2, 3, 4, 5]
    with list_lock:  # Acquire the lock before accessing the list
        for item in list1:
            shared_list.append(item)
            print(f"Added: {item}, List: {shared_list}")
    time.sleep(1)  # Simulate a delay

# Function for removing numbers from the list
def remove_from_list():
    with list_lock:  # Acquire the lock before accessing the list
        while shared_list:  # Ensure there is something to remove
            removed_number = shared_list.pop(0)
            print(f"Removed: {removed_number}, List: {shared_list}")
    time.sleep(1)  # Simulate a delay

# Create threads for adding and removing from the list
add_thread = threading.Thread(target=add_to_list)
remove_thread = threading.Thread(target=remove_from_list)

# Start the threads
add_thread.start()
add_thread.join()  # Ensure adding finishes before removal starts

remove_thread.start()
remove_thread.join()  # Wait for the removal to finish

# Final state of the list
print(f"Final List: {shared_list}")
# Out:
# Added: 1, List: [1]
# Added: 2, List: [1, 2]
# Added: 3, List: [1, 2, 3]
# Added: 4, List: [1, 2, 3, 4]
# Added: 5, List: [1, 2, 3, 4, 5]
# Removed: 1, List: [2, 3, 4, 5]
# Removed: 2, List: [3, 4, 5]
# Removed: 3, List: [4, 5]
# Removed: 4, List: [5]
# Removed: 5, List: []
# Final List: []

# %% [raw]
# # Q5. Describe the methods and tools available in Python for safely sharing data between threads and
# #     processes.
#
#
#
#
# Threading:
# Locks: The threading.Lock class is used to ensure that only one thread can access a shared resource at a time, preventing race conditions. Locks are acquired before accessing shared data and released afterward.
# RLocks: The threading.RLock (reentrant lock) allows a thread to acquire the same lock multiple times without causing a deadlock, useful for complex scenarios where a thread might need to re-acquire a lock it already holds.
# Queues: queue.Queue provides a thread-safe FIFO queue for communication between threads. It supports put and get operations that are atomic, ensuring thread safety.
#
# Multiprocessing:
# Locks: Similar to threading, multiprocessing.Lock is used to synchronize access to shared resources between processes.
# Manager Objects: The multiprocessing.Manager provides a way to create shared data structures, such as lists or dictionaries, which are managed by a separate process. This enables safe sharing of data across processes.
# Queues: multiprocessing.Queue allows for safe data exchange between processes. It operates similarly to queue.Queue but is designed for inter-process communication.

# %% [raw]
# #Q6. Discuss why it’s crucial to handle exceptions in concurrent programs and the techniques available for
# #    doing so. in 200 words each
#
#
#
# Handling exceptions in concurrent programs is crucial to ensure robustness and stability. Concurrency introduces complexities like race conditions, deadlocks, and resource conflicts, which can lead to unpredictable behavior and crashes if not managed properly.
#
# Why It's Crucial:
#
# Preventing Application Crashes: Unhandled exceptions can terminate a thread or process abruptly, causing potential loss of data or interruption of service.
# Resource Cleanup: Proper exception handling ensures that resources such as locks, files, or network connections are released or closed properly, preventing resource leaks.
# Debugging and Reliability: Handling exceptions provides visibility into errors and helps maintain the reliability of the system by allowing graceful recovery or logging of issues.
# Techniques for Handling Exceptions:
#
# Try-Except Blocks: Enclose code that might raise exceptions within try blocks and handle specific exceptions in except blocks. This allows for targeted error handling.
# Thread-Local Exception Handling: In multi-threaded programs, handle exceptions within each thread to ensure errors do not propagate and affect other threads.
# Process-Level Exception Handling: In multiprocessing, ensure that exceptions are caught and handled within each process. Use mechanisms like multiprocessing.Pool's apply_async with callbacks to handle results and errors.
# Logging: Implement logging to capture and review exception details, helping in diagnosing and fixing issues in concurrent executions.

# %%
# Q7. Create a program that uses a thread pool to calculate the factorial of numbers from 1 to 10 concurrently.
#     Use concurrent.futures.ThreadPoolExecutor to manage the threads.




import concurrent.futures
import math


def factorial(n):
    return math.factorial(n)

numbers = list(range(1, 11))


start = time.perf_counter()  # Start the timer

with concurrent.futures.ThreadPoolExecutor() as executor:
    results = list(executor.map(factorial, numbers))
    


for num, result in zip(numbers, results):
    print(f"Factorial of {num} is {result}")
# Out:
# Factorial of 1 is 1
# Factorial of 2 is 2
# Factorial of 3 is 6
# Factorial of 4 is 24
# Factorial of 5 is 120
# Factorial of 6 is 720
# Factorial of 7 is 5040
# Factorial of 8 is 40320
# Factorial of 9 is 362880
# Factorial of 10 is 3628800

# %%
# Q8. Create a Python program that uses multiprocessing.Pool to compute the square of numbers from 1 to 10 in
#     parallel. Measure the time taken to perform this computation using a pool of different sizes (e.g., 2, 4, 8
#     processes).





import multiprocessing
import time

# Function to compute the square of a number
def square(n):
    return n * n

# Function to measure execution time with a given pool size
def measure_time(pool_size):
    numbers = list(range(1, 11))
    
    start = time.perf_counter()  # Start the timer
    
    with multiprocessing.Pool(processes=pool_size) as pool:
        results = pool.map(square, numbers)
    
    end = time.perf_counter()  # End the timer
    elapsed_time = end - start
    
    return results, elapsed_time


pool_sizes = [2, 4, 8]  # Different pool sizes to test
    
for size in pool_sizes:
    results, elapsed_time = measure_time(size)
    print(f"Pool size: {size}")
    print(f"Results: {results}")
    print(f"Time taken: {elapsed_time:.2f} seconds")
    print()
# Out:
# Pool size: 2
# Results: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# Time taken: 0.03 seconds
#
# Pool size: 4
# Results: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# Time taken: 0.04 seconds
#
# Pool size: 8
# Results: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# Time taken: 0.07 seconds
